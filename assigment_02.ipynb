# %% [markdown]
# <a href="https://colab.research.google.com/github/alaseem/assignment-02/blob/main/assigment_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#1.0. Main Theme or Topic for the three datasets: Coffee

#1.1. Dataset 1 Title: Green coffee beans production, 1961 to 2023
#1.2. Dateset 1 URL: https://ourworldindata.org/grapher/coffee-bean-production?tab=table

#2.1. Dataset 2 Title: ICO Coffee Dataset (Worldwide)
#2.2. Dateset 2 URL: https://www.kaggle.com/datasets/yamaerenay/ico-coffee-dataset-worldwide

#3.1. Dataset 3 Title: Coffee Shop Sales
#3.2. Dateset 3 URL: https://mavenanalytics.io/data-playground/coffee-shop-sales

# %%
#importing pandas. Now we can use it directly by calling "pd"
import pandas as pd

# %%
# Dataset 1
csv_url = 'https://ourworldindata.org/grapher/coffee-bean-production.csv'
df = pd.read_csv(csv_url)

# %%
# run Dataset 1
df
# Out:
#         Entity Code  Year  \
# 0       Africa  NaN  1961
# 1       Africa  NaN  1962
# 2       Africa  NaN  1963
# 3       Africa  NaN  1964
# 4       Africa  NaN  1965
# ...        ...  ...   ...
# 7292  Zimbabwe  ZWE  2019
# 7293  Zimbabwe  ZWE  2020
# 7294  Zimbabwe  ZWE  2021
# 7295  Zimbabwe  ZWE  2022
# 7296  Zimbabwe  ZWE  2023
#
#       Coffee, green | 00000656 || Production | 005510 || tonnes
# 0                                             870970.00
# 1                                             883512.00
# 2                                             996674.00
# 3                                            1162048.00
# 4                                            1075084.00
# ...                                                 ...
# 7292                                             531.00
# 7293                                             579.00
# 7294                                             608.00
# 7295                                             681.00
# ...

# %%
# describe Dataset 1
df.describe()
# Out:
#               Year  Coffee, green | 00000656 || Production | 005510 || tonnes
# count  7297.000000                                       7.297000e+03
# mean   1991.395368                                       3.763072e+05
# std      18.149539                                       9.844460e+05
# min    1961.000000                                       0.000000e+00
# 25%    1976.000000                                       1.000000e+03
# 50%    1991.000000                                       2.121300e+04
# 75%    2007.000000                                       1.864210e+05
# max    2023.000000                                       1.123373e+07

# %%
# head Dataset 1
df.head()
# Out:
#    Entity Code  Year  \
# 0  Africa  NaN  1961
# 1  Africa  NaN  1962
# 2  Africa  NaN  1963
# 3  Africa  NaN  1964
# 4  Africa  NaN  1965
#
#    Coffee, green | 00000656 || Production | 005510 || tonnes
# 0                                           870970.0
# 1                                           883512.0
# 2                                           996674.0
# 3                                          1162048.0
# 4                                          1075084.0

# %%
# colums Dataset 1
df.columns
# Out:
# Index(['Entity', 'Code', 'Year',
#        'Coffee, green | 00000656 || Production | 005510 || tonnes'],
#       dtype='object')

# %%
# Dataset 2
csv_url_2= 'https://raw.githubusercontent.com/alaseem/assignment-02/a742fa99ad364ecf5ff68f53c21e6d578ee208f5/disappearance.csv'
df_2 = pd.read_csv(csv_url_2)

# %%
# run Dataset 2
df_2
# Out:
#             disappearance          1990          1991          1992  \
# 0                 Austria   1340.123985   1302.085970   1212.333964
# 1                 Belgium           NaN           NaN           NaN
# 2      Belgium/Luxembourg   1124.109984    708.156980    696.372979
# 3                Bulgaria    101.782998     16.761001    174.878012
# 4                 Croatia           NaN           NaN    134.545004
# 5                  Cyprus     30.570999     44.697000     39.303999
# 6          Czech Republic    659.433000    525.274000    472.156004
# 7                 Denmark    865.138999    908.542001    958.834999
# 8                 Estonia           NaN           NaN     12.909000
# 9                 Finland   1070.434998    965.553999   1030.327999
# 10                 France   5205.172363   5556.988033   5614.452697
# 11                Germany   7279.256961  12377.215949   9570.401951
# 12                 Greece    630.796004    386.942006    320.167003
# ...

# %%
# describe Dataset 2
df_2.describe()
# Out:
#                1990          1991          1992          1993          1994  \
# count     26.000000     26.000000     32.000000     33.000000     33.000000
# mean    2281.624435   2458.859614   2027.547802   2081.929419   1931.582442
# std     3783.777509   4264.404247   3635.548769   3865.332528   3374.339474
# min       19.612998     12.945002      1.554000      8.800001      5.646998
# 25%      447.905252    346.619758    129.783503    147.587998    163.862001
# 50%      886.309001    833.097500    716.418490    690.230001    799.610000
# 75%     2374.086511   2451.180759   1866.673771   1794.731013   1742.163407
# max    18297.618001  18661.180001  18290.452996  19217.136997  17326.103994
#
#                1995          1996          1997          1998          1999  \
# count     33.000000     33.000000     33.000000     33.000000     34.000000
# mean    1987.669992   2023.641621   2015.906083   2058.404766   2002.962215
# ...

# %%
# head Dataset 2
df_2.head()
# Out:
#            disappearance         1990         1991         1992         1993  \
# 0                Austria  1340.123985  1302.085970  1212.333964  1335.000982
# 1                Belgium          NaN          NaN          NaN          NaN
# 2     Belgium/Luxembourg  1124.109984   708.156980   696.372979   789.436984
# 3               Bulgaria   101.782998    16.761001   174.878012   326.955006
# 4                Croatia          NaN          NaN   134.545004   131.890000
#
#           1994         1995         1996         1997         1998  ...  \
# 0  1086.218996  1011.769996  1075.788000  1087.079597  1104.738197  ...
# 1          NaN          NaN          NaN          NaN          NaN  ...
# 2   958.214990  1073.014984  1038.637071   886.263764  1309.406477  ...
# 3   352.764006   393.408007   246.474995   274.918003   324.160004  ...
# 4   163.862001   288.481005   304.468998   361.396003   319.730000  ...
#
# ...

# %%
# columns Dataset 2
df_2.columns
# Out:
# Index(['disappearance', '1990', '1991', '1992', '1993', '1994', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016', '2017', '2018'],
#       dtype='object')

# %%
# Dataset 3
url_3 = 'https://github.com/alaseem/assignment-02/raw/a742fa99ad364ecf5ff68f53c21e6d578ee208f5/CoffeeShopSales.xlsx'
df_3 = pd.read_excel(url_3)

# %%
# run Dataset 3
df_3
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
# describe Dataset 3
df_3.describe()
# Out:
#        transaction_id               transaction_date  transaction_qty  \
# count   149116.000000                         149116    149116.000000
# mean     74737.371872  2023-04-15 11:50:32.173609984         1.438276
# min          1.000000            2023-01-01 00:00:00         1.000000
# 25%      37335.750000            2023-03-06 00:00:00         1.000000
# 50%      74727.500000            2023-04-24 00:00:00         1.000000
# 75%     112094.250000            2023-05-30 00:00:00         2.000000
# max     149456.000000            2023-06-30 00:00:00         8.000000
# std      43153.600016                            NaN         0.542509
#
#             store_id     product_id     unit_price
# count  149116.000000  149116.000000  149116.000000
# mean        5.342063      47.918607       3.382219
# min         3.000000       1.000000       0.800000
# 25%         3.000000      33.000000       2.500000
# 50%         5.000000      47.000000       3.000000
# ...

# %%
# head Dataset 3
df_3.head()
# Out:
#    transaction_id transaction_date transaction_time  transaction_qty  \
# 0               1       2023-01-01         07:06:11                2
# 1               2       2023-01-01         07:08:56                2
# 2               3       2023-01-01         07:14:04                2
# 3               4       2023-01-01         07:20:24                1
# 4               5       2023-01-01         07:22:41                2
#
#    store_id   store_location  product_id  unit_price    product_category  \
# 0         5  Lower Manhattan          32         3.0              Coffee
# 1         5  Lower Manhattan          57         3.1                 Tea
# 2         5  Lower Manhattan          59         4.5  Drinking Chocolate
# 3         5  Lower Manhattan          22         2.0              Coffee
# 4         5  Lower Manhattan          57         3.1                 Tea
#
#             product_type               product_detail
# 0  Gourmet brewed coffee                  Ethiopia Rg
# ...

# %%
# columns Dataset 3
df_3.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time',
#        'transaction_qty', 'store_id', 'store_location', 'product_id',
#        'unit_price', 'product_category', 'product_type', 'product_detail'],
#       dtype='object')

# %%
#3. Data quality issue
#3.1. Dataset 1 : Green coffee beans production, 1961 to 2023
#3.2. Dimension: Completeness
#3.3. Sub Dimension: completenessof mandatory attributes
#3.4. Details: Some countries have missing production data, which affects trend analysis and yearly comparisons

# %%
#3. Data quality issue
#3.1. Dataset: ICO Coffee Dataset (Worldwide)
#3.2. Dimension: Validity
#3.3. Sub Dimension: Meta-data compliance
#3.4. Details: Some columns contain numeric data stored as text. it harder to perform accurate numerical analysis.

# %% [markdown]
# Finish
